# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight

print("🚀 Starting VGG16 model training...")

# Paths
train_dir = 'resized_dataset_split/train'
val_dir = 'resized_dataset_split/val'
img_size = (224, 224)
batch_size = 32
epochs = 25

# Data Generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)
val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_data = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Class weights
labels = train_data.classes
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(labels), y=labels)
class_weights = dict(enumerate(class_weights))
print("📊 Class weights:", class_weights)

# VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze base

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
predictions = Dense(train_data.num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True),
    ReduceLROnPlateau(factor=0.2, patience=2)
]

# Training
history_vgg = model.fit(
    train_data,
    validation_data=val_data,
    epochs=epochs,
    class_weight=class_weights,
    callbacks=callbacks
)

# Save model
model.save("vgg16_balanced_model.h5")
print("✅ VGG16 training complete and saved as vgg16_balanced_model.h5")
# Out:
# 🚀 Starting VGG16 model training...
# Found 269 images belonging to 3 classes.
# Found 69 images belonging to 3 classes.
# 📊 Class weights: {0: 1.6011904761904763, 1: 0.5977777777777777, 2: 1.4232804232804233}
# c:\Users\venkatesh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 49s 5s/step - accuracy: 0.3758 - loss: 1.2956 - val_accuracy: 0.5797 - val_loss: 1.0601 - learning_rate: 0.0010
# Epoch 2/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.3814 - loss: 1.1944 - val_accuracy: 0.6377 - val_loss: 1.0329 - learning_rate: 0.0010
# Epoch 3/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 46s 5s/step - accuracy: 0.5194 - loss: 1.0513 - val_accuracy: 0.6667 - val_loss: 0.9879 - learning_rate: 0.0010
# Epoch 4/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 45s 5s/step - accuracy: 0.4185 - loss: 1.1189 - val_accuracy: 0.7391 - val_loss: 0.9499 - learning_rate: 0.0010
# Epoch 5/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 46s 5s/step - accuracy: 0.5118 - loss: 1.0088 - val_accuracy: 0.7681 - val_loss: 0.9130 - learning_rate: 0.0010
# Epoch 6/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 65s 8s/step - accuracy: 0.4412 - loss: 1.0906 - val_accuracy: 0.7826 - val_loss: 0.8946 - learning_rate: 0.0010
# Epoch 7/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 63s 7s/step - accuracy: 0.4722 - loss: 1.0046 - val_accuracy: 0.7826 - val_loss: 0.8609 - learning_rate: 0.0010
# Epoch 8/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 56s 7s/step - accuracy: 0.6299 - loss: 0.9824 - val_accuracy: 0.6812 - val_loss: 0.8345 - learning_rate: 0.0010
# Epoch 9/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 56s 6s/step - accuracy: 0.5722 - loss: 0.9986 - val_accuracy: 0.7681 - val_loss: 0.8134 - learning_rate: 0.0010
# Epoch 10/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 58s 6s/step - accuracy: 0.6025 - loss: 0.9026 - val_accuracy: 0.7681 - val_loss: 0.7804 - learning_rate: 0.0010
# Epoch 11/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 57s 6s/step - accuracy: 0.6407 - loss: 0.8727 - val_accuracy: 0.7826 - val_loss: 0.7546 - learning_rate: 0.0010
# Epoch 12/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 76s 6s/step - accuracy: 0.6561 - loss: 0.8839 - val_accuracy: 0.7681 - val_loss: 0.7456 - learning_rate: 0.0010
# Epoch 13/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 55s 6s/step - accuracy: 0.6856 - loss: 0.8150 - val_accuracy: 0.7826 - val_loss: 0.7223 - learning_rate: 0.0010
# Epoch 14/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 57s 6s/step - accuracy: 0.6368 - loss: 0.8400 - val_accuracy: 0.7826 - val_loss: 0.7113 - learning_rate: 0.0010
# Epoch 15/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 78s 9s/step - accuracy: 0.6734 - loss: 0.8162 - val_accuracy: 0.7971 - val_loss: 0.6990 - learning_rate: 0.0010
# Epoch 16/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 71s 8s/step - accuracy: 0.7158 - loss: 0.7670 - val_accuracy: 0.7971 - val_loss: 0.6919 - learning_rate: 0.0010
# Epoch 17/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 56s 6s/step - accuracy: 0.7023 - loss: 0.7982 - val_accuracy: 0.7971 - val_loss: 0.6796 - learning_rate: 0.0010
# Epoch 18/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 61s 7s/step - accuracy: 0.6502 - loss: 0.8314 - val_accuracy: 0.7971 - val_loss: 0.6687 - learning_rate: 0.0010
# Epoch 19/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 59s 7s/step - accuracy: 0.6845 - loss: 0.7727 - val_accuracy: 0.7826 - val_loss: 0.6478 - learning_rate: 0.0010
# Epoch 20/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 57s 6s/step - accuracy: 0.6809 - loss: 0.8045 - val_accuracy: 0.7971 - val_loss: 0.6420 - learning_rate: 0.0010
# Epoch 21/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 56s 6s/step - accuracy: 0.7070 - loss: 0.7732 - val_accuracy: 0.7826 - val_loss: 0.6319 - learning_rate: 0.0010
# Epoch 22/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 57s 6s/step - accuracy: 0.7181 - loss: 0.7475 - val_accuracy: 0.7971 - val_loss: 0.6252 - learning_rate: 0.0010
# Epoch 23/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 57s 6s/step - accuracy: 0.7261 - loss: 0.7489 - val_accuracy: 0.7971 - val_loss: 0.6192 - learning_rate: 0.0010
# Epoch 24/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 56s 6s/step - accuracy: 0.7096 - loss: 0.7196 - val_accuracy: 0.7971 - val_loss: 0.6120 - learning_rate: 0.0010
# Epoch 25/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.7399 - loss: 0.7296 - val_accuracy: 0.7826 - val_loss: 0.6000 - learning_rate: 0.0010
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ VGG16 training complete and saved as vgg16_balanced_model.h5
